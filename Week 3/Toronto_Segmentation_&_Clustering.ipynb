# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhavpratyaksh/Coursera_Capstone/blob/master/Week%203/Toronto_Segmentation_%26_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Toronto Neigbourhoods Segmentation & Clustering
#
# ## Applied Data Science Capstone Project | Week 3 | Peer-Graded Assignment
# ## Prabhav Pratyaksh 26th July 2021

# %% [markdown]
# ### Importing libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
# !pip install geocoder
import geocoder
# !pip install geopy
from geopy.geocoders import Nominatim 
import folium
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
print("All libraries installed")
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2021.5.30)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Requirement already satisfied: geopy in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.7/dist-packages (from geopy) (1.52)
# All libraries installed

# %% [markdown]
# ### Part 1 - Webscraping

# %%
# send request to Wikipedia link
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
response = requests.get(url).text

# using BeautifulSoup, get relevant tags for parsing
soup = BeautifulSoup(response, 'html5lib')
table = soup.find('table')
fields = table.find_all('td')
#print(soup.prettify())

df_1 = pd.DataFrame(columns=["Postal Code","Borough","Neighbourhood(s)"]) # creating a dataframe to add the values

# iterating through every column to separate the postal codes, boroughs, and the neigbourhoods
for cell in fields:
  if cell.span.text=='Not assigned':
        pass
  else:
      PC = cell.p.text[:3]
      BH = (cell.span.text).split('(')[0]
      NB = (((((cell.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
      df_1 = df_1.append({"Postal Code":PC,"Borough":BH,"Neighbourhood(s)":NB},ignore_index = True)

df_1['Borough']=df_1['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

df_1.head()
print ("Dataframe has {} rows and {} columns".format(df_1.shape[0],df_1.shape[1]))
# Out:
# Dataframe has 103 rows and 3 columns

# %%
#Checking if there are any Neighbourhoods with Not Assigned value
df_1.filter(like = "Not assigned", axis = 0)
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood(s)]
# Index: []

# %% [markdown]
# From the above code snippet, we see that there are no rows (both Boroughs and Neighbourhoods) that have Not Assigned value. This is because we already removed those while scraping
#
# However, in case there were Boroughs with Not Assigned values, we could have used the below code to drop them from the dataframe

# %%
df_1.drop(df_1[df_1['Borough'] == 'Not assigned'].index, inplace=True)
print("Dataframe now has {} rows and {} columns".format(df_1.shape[0],df_1.shape[1]))
df_1.head()
# Out:
# Dataframe now has 103 rows and 3 columns
#   Postal Code           Borough                  Neighbourhood(s)
# 0         M3A        North York                         Parkwoods
# 1         M4A        North York                  Victoria Village
# 2         M5A  Downtown Toronto         Regent Park, Harbourfront
# 3         M6A        North York  Lawrence Manor, Lawrence Heights
# 4         M7A      Queen's Park     Ontario Provincial Government

# %% [markdown]
# Note that there are same number of rows and columns after dropping

# %% [markdown]
# Similarly, we could have used the below code to replace Neighbourhoods with Not assigned value with their respective Boroughs. However, as seen above there are no Boroughs or Neighbourhoods with Not assigned value

# %%
df_1.loc[df_1['Neighbourhood(s)'] == "Not assigned", "Neighbourhood(s)"] = df_1.loc[df_1['Neighbourhood(s)'] == "Not assigned", "Borough"]
df_1
# Out:
#     Postal Code  ...                                   Neighbourhood(s)
# 0           M3A  ...                                          Parkwoods
# 1           M4A  ...                                   Victoria Village
# 2           M5A  ...                          Regent Park, Harbourfront
# 3           M6A  ...                   Lawrence Manor, Lawrence Heights
# 4           M7A  ...                      Ontario Provincial Government
# ..          ...  ...                                                ...
# 98          M8X  ...      The Kingsway, Montgomery Road, Old Mill North
# 99          M4Y  ...                               Church and Wellesley
# 100         M7Y  ...                                     Enclave of M4L
# 101         M8Y  ...  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# Now, we group Neighbourhoods by postal code

# %%
df_1 = df_1.groupby(['Postal Code', 'Borough'])['Neighbourhood(s)'].apply(', '.join).reset_index()
df_1.columns = ['Postal Code', 'Borough', 'Neighbourhood(s)']
df_1
# Out:
#     Postal Code  ...                                   Neighbourhood(s)
# 0           M1B  ...                                     Malvern, Rouge
# 1           M1C  ...             Rouge Hill, Port Union, Highland Creek
# 2           M1E  ...                  Guildwood, Morningside, West Hill
# 3           M1G  ...                                             Woburn
# 4           M1H  ...                                          Cedarbrae
# ..          ...  ...                                                ...
# 98          M9N  ...                                             Weston
# 99          M9P  ...                                          Westmount
# 100         M9R  ...  Kingsview Village, St. Phillips, Martin Grove ...
# 101         M9V  ...  South Steeles, Silverstone, Humbergate, Jamest...
# 102         M9W  ...  Clairville, Humberwood, Woodbine Downs, West H...
#
# [103 rows x 3 columns]

# %%
print("Dataframe now has {} rows and {} columns".format(df_1.shape[0],df_1.shape[1]))
# Out:
# Dataframe now has 103 rows and 3 columns

# %% [markdown]
# ### Part 2 - Geographical Coordinates

# %% [markdown]
# For this part, Geocoder API caused the kernel to hang. Hence, I have used the CSV file provided

# %%
# Reading the geospatial coordinates file as a dataframe
filepath = r'/content/Geospatial_Coordinates.csv'
coordinates = pd.read_csv (filepath)

# Merging the 2 dataframes based on the postal codes

df_2 = df_1.merge(coordinates, 'inner', "Postal Code")
df_2
# Out:
#     Postal Code              Borough  ...   Latitude  Longitude
# 0           M1B          Scarborough  ...  43.806686 -79.194353
# 1           M1C          Scarborough  ...  43.784535 -79.160497
# 2           M1E          Scarborough  ...  43.763573 -79.188711
# 3           M1G          Scarborough  ...  43.770992 -79.216917
# 4           M1H          Scarborough  ...  43.773136 -79.239476
# ..          ...                  ...  ...        ...        ...
# 98          M9N                 York  ...  43.706876 -79.518188
# 99          M9P            Etobicoke  ...  43.696319 -79.532242
# 100         M9R            Etobicoke  ...  43.688905 -79.554724
# 101         M9V            Etobicoke  ...  43.739416 -79.588437
# 102         M9W  Etobicoke Northwest  ...  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %% [markdown]
# ### Part 3 - Segmentation & Clustering of Neighbourhoods

# %% [markdown]
# For this part, only boroughs with Toronto will be analysed

# %%
df = df_2[df_2["Borough"].str.contains("Toronto")]
df.reset_index(drop=True,inplace=True)
df
# Out:
#    Postal Code                 Borough  ...   Latitude  Longitude
# 0          M4E            East Toronto  ...  43.676357 -79.293031
# 1          M4J  East York/East Toronto  ...  43.685347 -79.338106
# 2          M4K            East Toronto  ...  43.679557 -79.352188
# 3          M4L            East Toronto  ...  43.668999 -79.315572
# 4          M4M            East Toronto  ...  43.659526 -79.340923
# 5          M4N         Central Toronto  ...  43.728020 -79.388790
# 6          M4P         Central Toronto  ...  43.712751 -79.390197
# 7          M4R         Central Toronto  ...  43.715383 -79.405678
# 8          M4S         Central Toronto  ...  43.704324 -79.388790
# 9          M4T         Central Toronto  ...  43.689574 -79.383160
# 10         M4V         Central Toronto  ...  43.686412 -79.400049
# 11         M4W        Downtown Toronto  ...  43.679563 -79.377529
# 12         M4X        Downtown Toronto  ...  43.667967 -79.367675
# 13         M4Y        Downtown Toronto  ...  43.665860 -79.383160
# 14         M5A        Downtown Toronto  ...  43.654260 -79.360636
# 15         M5B        Downtown Toronto  ...  43.657162 -79.378937
# 16         M5C        Downtown Toronto  ...  43.651494 -79.375418
# 17         M5E        Downtown Toronto  ...  43.644771 -79.373306
# 18         M5G        Downtown Toronto  ...  43.657952 -79.387383
# 19         M5H        Downtown Toronto  ...  43.650571 -79.384568
# 20         M5J        Downtown Toronto  ...  43.640816 -79.381752
# 21         M5K        Downtown Toronto  ...  43.647177 -79.381576
# 22         M5L        Downtown Toronto  ...  43.648198 -79.379817
# 23         M5N         Central Toronto  ...  43.711695 -79.416936
# 24         M5P         Central Toronto  ...  43.696948 -79.411307
# 25         M5R         Central Toronto  ...  43.672710 -79.405678
# 26         M5S        Downtown Toronto  ...  43.662696 -79.400049
# 27         M5T        Downtown Toronto  ...  43.653206 -79.400049
# 28         M5V        Downtown Toronto  ...  43.628947 -79.394420
# 29         M5W  Downtown Toronto Stn A  ...  43.646435 -79.374846
# 30         M5X        Downtown Toronto  ...  43.648429 -79.382280
# 31         M6G        Downtown Toronto  ...  43.669542 -79.422564
# 32         M6H            West Toronto  ...  43.669005 -79.442259
# 33         M6J            West Toronto  ...  43.647927 -79.419750
# 34         M6K            West Toronto  ...  43.636847 -79.428191
# 35         M6P            West Toronto  ...  43.661608 -79.464763
# 36         M6R            West Toronto  ...  43.648960 -79.456325
# 37         M6S            West Toronto  ...  43.651571 -79.484450
# 38         M7Y   East Toronto Business  ...  43.662744 -79.321558
#
# [39 rows x 5 columns]

# %% [markdown]
# Now, we visualize these neighbourhoods on a map of Toronto.
#
# But before we do that, we need to place Toronto on the map

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(f"The latitiude and longitude of Toronto are {latitude},{longitude}")
# Out:
# The latitiude and longitude of Toronto are 43.6534817,-79.3839347

# %%
# create map of Toronto using latitude and longitude values
map_tor = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood(s)']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_tor)  
    
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_8ff30622fbfb4a22a443cbcbf2401983%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8ff30622fbfb4a22a443cbcbf2401983%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_8ff30622fbfb4a22a443cbcbf2401983%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_8ff30622fbfb4a22a443cbcbf2401983%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_5947fad457ec4bf686cb52b174386863%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# First, we define the our Foursquare credentials

# %%
CLIENT_ID = 'Not revealing' # your Foursquare ID
CLIENT_SECRET = 'Not revealing this too' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Not revealing
# CLIENT_SECRET:Not revealing this too

# %% [markdown]
# Now, let's explore a neighbourhood. For this task, we will look at 100 venues within a radius of 500m

# %%
nbhr = 'Trinity'
nbhr_df = df[df['Neighbourhood(s)'].str.contains(nbhr)]
nbhr_df
lat = nbhr_df.iloc[0,-2]
lng = nbhr_df.iloc[0,-1]
print(f"Latitude and longitude values of {nbhr} are {lat}, {lng}.")
# Out:
# Latitude and longitude values of Trinity are 43.647926700000006, -79.4197497.

# %%
#Foursquare credentials
client_id = CLIENT_ID
client_secret = CLIENT_SECRET
version = '20180605'
limit = 100
radius = 500

# %%
# URL request construction
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    client_id, 
    client_secret, 
    version, 
    lat, 
    lng, 
    radius, 
    limit)

#result of request stored in results
results = requests.get(url).json()
print("Request successful.")
# Out:
# Request successful.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we clean the response received (in JSON) by converting to a pandas dataframe

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

print(f"{nearby_venues.shape[0]} venues were returned by Foursquare.")
nearby_venues.head()
# Out:
# 42 venues were returned by Foursquare.
#                            name        categories        lat        lng
# 0             Pizzeria Libretto       Pizza Place  43.648979 -79.420604
# 1             Bellwoods Brewery           Brewery  43.647097 -79.419955
# 2                 Foxley Bistro  Asian Restaurant  43.648643 -79.420495
# 3  Bang Bang Ice Cream & Bakery    Ice Cream Shop  43.646246 -79.419553
# 4               Paris Paris Bar          Wine Bar  43.649237 -79.421436

# %%
# Some preliminary analysis on nearby_venues
top_venues = nearby_venues['categories'].value_counts()
top_venues.loc[top_venues >1]
# Out:
# Bar                      3
# Asian Restaurant         2
# Diner                    2
# Vietnamese Restaurant    2
# Café                     2
# Men's Store              2
# Restaurant               2
# Name: categories, dtype: int64

# %% [markdown]
# Now we explore venues in all neighbourhoods

# %%
def get_nearby_venues(names, lats, lngs, radius=500, limit=100):
    venues_list = []
    for name, lat, lng in zip(names, lats, lngs):
        # specify the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id,
            client_secret,
            version,
            lat,
            lng,
            radius,
            limit)
        # make the request, store the response
        results = requests.get(url).json()['response']['groups'][0]['items']
        # extract relevant information from each venue
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
    # populate the dataframe with venues list
    venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    venues.columns = ['Neighborhood',
                      'Neighborhood Latitude',
                      'Neighborhood Longitude',
                      'Venue',
                      'Venue Latitude',
                      'Venue Longitude',
                      'Venue Category']
    return(venues)

# %% [markdown]
# Now, we will use the above function on all neighbourhoods

# %%
all_venues = get_nearby_venues(
    df['Neighbourhood(s)'],
    df['Latitude'],
    df['Longitude']
)
all_venues
# Out:
#         Neighborhood  ...        Venue Category
# 0        The Beaches  ...                 Trail
# 1        The Beaches  ...     Health Food Store
# 2        The Beaches  ...                   Pub
# 3        The Beaches  ...          Neighborhood
# 4        The Beaches  ...      Asian Restaurant
# ...              ...  ...                   ...
# 1602  Enclave of M4L  ...                Garden
# 1603  Enclave of M4L  ...    Light Rail Station
# 1604  Enclave of M4L  ...                  Park
# 1605  Enclave of M4L  ...               Butcher
# 1606  Enclave of M4L  ...  Gym / Fitness Center
#
# [1607 rows x 7 columns]

# %%
print(f"In all the neighbourhoods, there are {all_venues.shape[0]} venues across {all_venues['Venue Category'].nunique()} categories")
all_venues[['Neighborhood', 'Venue']].groupby('Neighborhood').count()
# Out:
# In all the neighbourhoods, there are 1607 venues across 237 categories
#                                                     Venue
# Neighborhood
# Berczy Park                                            57
# Brockton, Parkdale Village, Exhibition Place           27
# CN Tower, King and Spadina, Railway Lands, Harb...     17
# Central Bay Street                                     68
# Christie                                               16
# Church and Wellesley                                   78
# Commerce Court, Victoria Hotel                        100
# Davisville                                             35
# Davisville North                                       10
# Dufferin, Dovercourt Village                           17
# Enclave of M4L                                         15
# Enclave of M5E                                         98
# First Canadian Place, Underground city                100
# Forest Hill North & West                                4
# Garden District, Ryerson                              100
# Harbourfront East, Union Station, Toronto Islands     100
# High Park, The Junction South                          24
# India Bazaar, The Beaches West                         20
# Kensington Market, Chinatown, Grange Park              64
# Lawrence Park                                           4
# Little Portugal, Trinity                               42
# Moore Park, Summerhill East                             2
# North Toronto West                                     17
# Parkdale, Roncesvalles                                 14
# Regent Park, Harbourfront                              46
# Richmond, Adelaide, King                              100
# Rosedale                                                4
# Roselawn                                                3
# Runnymede, Swansea                                     36
# St. James Town                                         89
# St. James Town, Cabbagetown                            45
# Studio District                                        36
# Summerhill West, Rathnelly, South Hill, Forest ...     15
# The Annex, North Midtown, Yorkville                    19
# The Beaches                                             5
# The Danforth  East                                      3
# The Danforth West, Riverdale                           42
# Toronto Dominion Centre, Design Exchange              100
# University of Toronto, Harbord                         35

# %% [markdown]
# Now, we move to analyze each neighbourhood. To do that, we use one-hot encoding to make our analysis easier

# %%
# one hot encoding
all_venue_onehot = pd.get_dummies(all_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
all_venue_onehot['Neighborhood'] = all_venues['Neighborhood'] 
all_venue_onehot = all_venue_onehot.groupby('Neighborhood').mean().reset_index()

all_venue_onehot.head()
# Out:
#                                         Neighborhood  ...  Yoga Studio
# 0                                        Berczy Park  ...     0.000000
# 1       Brockton, Parkdale Village, Exhibition Place  ...     0.000000
# 2  CN Tower, King and Spadina, Railway Lands, Har...  ...     0.000000
# 3                                 Central Bay Street  ...     0.014706
# 4                                           Christie  ...     0.000000
#
# [5 rows x 237 columns]

# %%
# Displaying top venues in each neighbourhood
def top_venues(row, num_venues):
    row_cats = row.iloc[1:]
    row_cats_sorted = row_cats.sort_values(ascending=False)
    return row_cats_sorted.index.values[0:num_venues]



num_venues = 10
indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
cols = ['Neighborhood']
for i in np.arange(num_venues):
    try:
        cols.append(f"{i+1}{indicators[i]} Most Common Venue")
    except:
        cols.append(f"{i+1}th Most Common Venue")

# create a dataframe of 10 most common venues by neighborhood
all_common = pd.DataFrame(columns=cols)
all_common['Neighborhood'] = all_venue_onehot['Neighborhood']

for i in np.arange(all_venue_onehot.shape[0]):
    all_common.iloc[i, 1:] = top_venues(all_venue_onehot.iloc[i, :], num_venues)

all_common
# Out:
#                                          Neighborhood  ...    10th Most Common Venue
# 0                                         Berczy Park  ...                       Pub
# 1        Brockton, Parkdale Village, Exhibition Place  ...                       Bar
# 2   CN Tower, King and Spadina, Railway Lands, Har...  ...                     Plane
# 3                                  Central Bay Street  ...                       Spa
# 4                                            Christie  ...               Coffee Shop
# 5                                Church and Wellesley  ...  Mediterranean Restaurant
# 6                      Commerce Court, Victoria Hotel  ...       American Restaurant
# 7                                          Davisville  ...        Salon / Barbershop
# 8                                    Davisville North  ...               Pizza Place
# 9                        Dufferin, Dovercourt Village  ...               Music Venue
# 10                                     Enclave of M4L  ...      Fast Food Restaurant
# 11                                     Enclave of M5E  ...                    Bakery
# 12             First Canadian Place, Underground city  ...                    Bakery
# 13                           Forest Hill North & West  ...         Electronics Store
# 14                           Garden District, Ryerson  ...                     Diner
# 15  Harbourfront East, Union Station, Toronto Islands  ...                      Park
# 16                      High Park, The Junction South  ...            Discount Store
# 17                     India Bazaar, The Beaches West  ...        Italian Restaurant
# 18          Kensington Market, Chinatown, Grange Park  ...               Gaming Cafe
# 19                                      Lawrence Park  ...               Escape Room
# 20                           Little Portugal, Trinity  ...                   Brewery
# 21                        Moore Park, Summerhill East  ...         Electronics Store
# 22                                 North Toronto West  ...                Restaurant
# 23                             Parkdale, Roncesvalles  ...                 Bookstore
# 24                          Regent Park, Harbourfront  ...         French Restaurant
# 25                           Richmond, Adelaide, King  ...          Sushi Restaurant
# 26                                           Rosedale  ...       Dumpling Restaurant
# 27                                           Roselawn  ...         Electronics Store
# 28                                 Runnymede, Swansea  ...                    School
# 29                                     St. James Town  ...                      Park
# 30                        St. James Town, Cabbagetown  ...                   Butcher
# 31                                    Studio District  ...          Stationery Store
# 32  Summerhill West, Rathnelly, South Hill, Forest...  ...          Sushi Restaurant
# 33                The Annex, North Midtown, Yorkville  ...         Indian Restaurant
# 34                                        The Beaches  ...       Dumpling Restaurant
# 35                                 The Danforth  East  ...         Electronics Store
# 36                       The Danforth West, Riverdale  ...                Restaurant
# 37           Toronto Dominion Centre, Design Exchange  ...          Asian Restaurant
# 38                     University of Toronto, Harbord  ...              Noodle House
#
# [39 rows x 11 columns]

# %% [markdown]
# Now, we move to the actual clustering analysis

# %%
kclusters = 5

all_common_cluster = all_venue_onehot.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=1).fit(all_common_cluster)

kmeans.labels_
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 0, 4, 4, 4, 4, 4, 1, 4, 3,
#        4, 4, 4, 4, 0, 2, 4, 4, 4, 4, 4, 4, 4, 1, 4, 4, 4], dtype=int32)

# %%
# Creating a new dataframe containing 10 most common venues and their labels

all_common.insert(0, 'Cluster Label', kmeans.labels_)


all_merged = df.copy()

all_merged = all_merged.join(all_common.set_index('Neighborhood'), on='Neighbourhood(s)')

all_merged.head()
# Out:
#   Postal Code  ... 10th Most Common Venue
# 0         M4E  ...    Dumpling Restaurant
# 1         M4J  ...      Electronics Store
# 2         M4K  ...             Restaurant
# 3         M4L  ...     Italian Restaurant
# 4         M4M  ...       Stationery Store
#
# [5 rows x 16 columns]

# %% [markdown]
# Visualizing the clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.gist_rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
for lat, lng, nbhd, cluster in zip(all_merged['Latitude'],
                                   all_merged['Longitude'],
                                   all_merged['Neighbourhood(s)'],
                                   all_merged['Cluster Label']):
    label = folium.Popup(f"Cluster {cluster}: {nbhd}", parse_html=True)
    folium.CircleMarker([lat, lng],
                        radius=5,
                        popup=label,
                        color=rainbow[cluster-1],
                        fill=True,
                        fill_color=rainbow[cluster-1],
                        fill_opacity=0.5
                       ).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_86b5eb6255604d2583cc1d129e6ec14c%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_86b5eb6255604d2583cc1d129e6ec14c%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_86b5eb6255604d2583cc1d129e6ec14c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_86b5eb6255604d2583cc1d129e6ec14c%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_eacff880d16641cf924ed478816892db%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# Examination and uniqueness of each cluster

# %% [markdown]
# **Cluster 0**

# %%
cluster0 = all_merged.loc[all_merged['Cluster Label'] == 0,
                          all_merged.columns[[2] + list(range(6, all_merged.shape[1]))]
                         ].reset_index(drop=True)

print("Most common venue types: \n", cluster0['1st Most Common Venue'].value_counts())

cluster0
# Out:
# Most common venue types:
#  Jewelry Store    1
# Park             1
# Name: 1st Most Common Venue, dtype: int64
#            Neighbourhood(s)  ... 10th Most Common Venue
# 0                  Rosedale  ...    Dumpling Restaurant
# 1  Forest Hill North & West  ...      Electronics Store
#
# [2 rows x 11 columns]

# %% [markdown]
# **Cluster 1**

# %%
cluster1 = all_merged.loc[all_merged['Cluster Label'] == 1,
                          all_merged.columns[[2] + list(range(6, all_merged.shape[1]))]
                         ].reset_index(drop=True)

print("Most common venue types: \n", cluster1['1st Most Common Venue'].value_counts())

cluster1
# Out:
# Most common venue types:
#  Intersection    1
# Park            1
# Name: 1st Most Common Venue, dtype: int64
#      Neighbourhood(s)  ... 10th Most Common Venue
# 0  The Danforth  East  ...      Electronics Store
# 1       Lawrence Park  ...            Escape Room
#
# [2 rows x 11 columns]

# %% [markdown]
# **Cluster 2**

# %%
cluster2 = all_merged.loc[all_merged['Cluster Label'] == 2,
                          all_merged.columns[[2] + list(range(6, all_merged.shape[1]))]
                         ].reset_index(drop=True)

print("Most common venue types: \n", cluster2['1st Most Common Venue'].value_counts())
cluster2
# Out:
# Most common venue types:
#  Garden    1
# Name: 1st Most Common Venue, dtype: int64
#   Neighbourhood(s)  ... 10th Most Common Venue
# 0         Roselawn  ...      Electronics Store
#
# [1 rows x 11 columns]

# %% [markdown]
# **Cluster 3**

# %%
cluster3 = all_merged.loc[all_merged['Cluster Label'] == 3,
                          all_merged.columns[[2] + list(range(6, all_merged.shape[1]))]
                         ].reset_index(drop=True)

print("Most common venue types: \n", cluster3['1st Most Common Venue'].value_counts())
cluster3
# Out:
# Most common venue types:
#  Trail    1
# Name: 1st Most Common Venue, dtype: int64
#               Neighbourhood(s)  ... 10th Most Common Venue
# 0  Moore Park, Summerhill East  ...      Electronics Store
#
# [1 rows x 11 columns]

# %% [markdown]
# **Cluster 4**

# %%
cluster4 = all_merged.loc[all_merged['Cluster Label'] == 4,
                          all_merged.columns[[2] + list(range(6, all_merged.shape[1]))]
                         ].reset_index(drop=True)

print("Most common venue types: \n", cluster4['1st Most Common Venue'].value_counts())
cluster4
# Out:
# Most common venue types:
#  Coffee Shop             15
# Café                     5
# Gym / Fitness Center     2
# Bar                      1
# Pharmacy                 1
# Breakfast Spot           1
# Pub                      1
# Grocery Store            1
# Park                     1
# Greek Restaurant         1
# Airport Service          1
# Thai Restaurant          1
# Dessert Shop             1
# Cocktail Bar             1
# Name: 1st Most Common Venue, dtype: int64
#                                      Neighbourhood(s)  ...    10th Most Common Venue
# 0                                         The Beaches  ...       Dumpling Restaurant
# 1                        The Danforth West, Riverdale  ...                Restaurant
# 2                      India Bazaar, The Beaches West  ...        Italian Restaurant
# 3                                     Studio District  ...          Stationery Store
# 4                                    Davisville North  ...               Pizza Place
# 5                                  North Toronto West  ...                Restaurant
# 6                                          Davisville  ...        Salon / Barbershop
# 7   Summerhill West, Rathnelly, South Hill, Forest...  ...          Sushi Restaurant
# 8                         St. James Town, Cabbagetown  ...                   Butcher
# 9                                Church and Wellesley  ...  Mediterranean Restaurant
# 10                          Regent Park, Harbourfront  ...         French Restaurant
# 11                           Garden District, Ryerson  ...                     Diner
# 12                                     St. James Town  ...                      Park
# 13                                        Berczy Park  ...                       Pub
# 14                                 Central Bay Street  ...                       Spa
# 15                           Richmond, Adelaide, King  ...          Sushi Restaurant
# 16  Harbourfront East, Union Station, Toronto Islands  ...                      Park
# 17           Toronto Dominion Centre, Design Exchange  ...          Asian Restaurant
# 18                     Commerce Court, Victoria Hotel  ...       American Restaurant
# 19                The Annex, North Midtown, Yorkville  ...         Indian Restaurant
# 20                     University of Toronto, Harbord  ...              Noodle House
# 21          Kensington Market, Chinatown, Grange Park  ...               Gaming Cafe
# 22  CN Tower, King and Spadina, Railway Lands, Har...  ...                     Plane
# 23                                     Enclave of M5E  ...                    Bakery
# 24             First Canadian Place, Underground city  ...                    Bakery
# 25                                           Christie  ...               Coffee Shop
# 26                       Dufferin, Dovercourt Village  ...               Music Venue
# 27                           Little Portugal, Trinity  ...                   Brewery
# 28       Brockton, Parkdale Village, Exhibition Place  ...                       Bar
# 29                      High Park, The Junction South  ...            Discount Store
# 30                             Parkdale, Roncesvalles  ...                 Bookstore
# 31                                 Runnymede, Swansea  ...                    School
# 32                                     Enclave of M4L  ...      Fast Food Restaurant
#
# [33 rows x 11 columns]

# %% [markdown]
# ##### Thanks for reviewing!
